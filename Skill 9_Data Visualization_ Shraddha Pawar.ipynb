# %% [markdown]
# ## Skill 9
# ### Name : Shraddha Pawar
# ### Batch : ML 18
# ### Title :Visualize the dataset for presentation

# %% [markdown]
# ### Problem statement

# %% [markdown]
# Visualize the sample superstore dataset

# %%
# Import libraries

import pandas as pd                                    
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt  
import plotly.express as px

# %%
# Read dataset

df = pd.read_excel("SampleSuperstore.csv.xlsx")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### Data Information and insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   float64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   float64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
#  13  Profit/Loss   9994 non-null   object
# dtypes: float64(5), object(9)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0      42420.0  South        Furniture    Bookcases  261.9600       2.0
# 1      42420.0  South        Furniture       Chairs  731.9400       3.0
# 2      90036.0   West  Office Supplies       Labels   14.6200       2.0
# 3      33311.0  South        Furniture       Tables  957.5775       5.0
# 4      33311.0  South  Office Supplies      Storage   22.3680       2.0
#
#    Discount    Profit Profit/Loss
# 0      0.00   41.9136      Profit
# ...

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Profit/Loss'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 14)

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# Profit/Loss     0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Univariate analysis

# %%
plt.plot("Sales",data=df,marker = "*")

font1 = {'family':'serif','color':'green','size':20}
plt.title("Line plot",fontdict = font1)
plt.show()

# %% [markdown]
# The above plot shows the sales of the suprestore.
#
# Maximum sales is upto 5000.

# %%
plt.plot("Profit",data=df,marker = "o",color="b", linestyle = "dotted")
font1 = {'family':'serif','color':'green','size':20}
plt.title("Line plot",fontdict = font1)
plt.show()

# %% [markdown]
# The above plot shows the profit and loss of superstore.

# %%
# Countplot

sns.countplot(x='Quantity', data=df )
plt.title("Count plot")
# Out:
# Text(0.5, 1.0, 'Count plot')

# %% [markdown]
# Maximum 2 to 3 products purchased in superstore.

# %% [markdown]
# ### Bivariate analysis

# %%
sns.set_context('paper')
 
# create plot
sns.barplot(x = 'Profit/Loss', y = 'Profit', data = df,
            palette = 'PuRd')
font1 = {'family':'serif','color':'black','size':20}
plt.title("Profit loss Plot",fontdict = font1)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# From the above plot, loss of superstore is maximum than profit.

# %%
fig = px.pie(df, values='Sales', names='Category')
fig.show()
# Out:
# <div>                            <div id="6954b93c-b75f-45be-8df5-2195bf000574" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6954b93c-b75f-45be-8df5-2195bf000574")) {                    Plotly.newPlot(                        "6954b93c-b75f-45be-8df5-2195bf000574",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Category=%{label}<br>Sales=%{value}<extra></extra>","labels":["Furniture","Furniture","Office Supplies","Furniture","Office Supplies","Furniture","Office Supplies","Technology","Office Supplies","Office Supplies","Furniture","Technology","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Technology","Office Supplies","Office Supplie
# ...

# %%
# Scatter plot

sns.scatterplot(x='Profit', y='Sales', hue='Profit/Loss', data=df, palette ='YlOrRd' )
font1 = {'family':'serif','color':'black','size':20}
plt.title("Superstore Dataset",fontdict = font1)
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
sns.set_context('paper')
 
# create plot
sns.countplot(x = 'Segment', hue = 'Profit/Loss' ,data = df, palette = 'magma')
plt.show()

# %%
sns.set_context('paper')
 
# create plot
sns.barplot(x = 'Quantity', y = 'Sales', data = df,
            palette = 'PuRd')
font1 = {'family':'serif','color':'black','size':20}
plt.title("Sales Plot",fontdict = font1)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(data = df,hue = 'Profit/Loss',diag_kind = "kde",kind = "scatter",palette = "husl")

# %%
# Correlation plot

corr=df.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlOrRd")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# The above analysis provides some results:
#
# Maximum sales is upto 5000.
#
# Maximum 2 to 3 products purchased in superstore.
#
# Loss of superstore is maximum than profit.
