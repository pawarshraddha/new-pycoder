# %% [markdown]
# ## Data visualization by Using Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
df=sns.load_dataset('dots')
df
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
print(df.head())
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %% [markdown]
# ### Styling and Themes in Seaborn

# %%
plt.scatter(df.time , df.firing_rate)                      # simple plot


plt.show()

# %%
plt.scatter(df.time , df.firing_rate)



font1 = {'family':'serif','color':'red','size':20}
font2 = {'family':'serif','color':'blue','size':15}

plt.xlabel('Time', fontdict = font2)
plt.ylabel('firing_rate', fontdict = font2)
plt.title('Dots analysis', fontdict = font1)
# Out:
# Text(0.5, 1.0, 'Dots analysis')

# %%
plt.scatter(df.time , df.firing_rate)
sns.set()                                                 # plot by using seaborn
plt.show()

# %%
plt.scatter(df.time , df.firing_rate)                                      #  plot by using seaborn
sns.set_style("whitegrid")                                                 #  dark,white,ticks


font1 = {'family':'serif','color':'red','size':20}
font2 = {'family':'serif','color':'blue','size':15}

plt.xlabel('Time', fontdict = font2)
plt.ylabel('firing_rate', fontdict = font2)
plt.title('Dots analysis', fontdict = font1)
# Out:
# Text(0.5, 1.0, 'Dots analysis')

# %% [markdown]
# conclusion : - By using graph if time is near about zero so our firing rate is incresses upto 70.

# %%
plt.scatter(df.time , df.firing_rate)
sns.set_style("dark")                                                   # by using dark gridline
sns.despine()

# %%
plt.scatter('time','firing_rate',data=df)
sns.set_style("darkgrid", {'grid.color': 'g'})                          # Green grid lines
sns.despine()

# %%
plt.scatter(df.time , df.firing_rate)
sns.set_style("dark")                         
sns.set_context("paper")                                         # context style is paper

# %%
plt.scatter(df.time , df.firing_rate)
sns.set_style("dark")
sns.set_context("notebook")                                        # context style is notebook

# %% [markdown]
# ### Plotting with the relplot function

# %%
dots = sns.load_dataset("dots")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
dots['align'].unique()                        # types of align
# Out:
# array(['dots', 'sacc'], dtype=object)

# %%
sns.relplot(data=dots, x="time", y="firing_rate")                       # used relplot

# %%
sns.relplot(data=df, x="time", y="firing_rate", hue="align")           #to establish relation betn two variables--relplot

# %% [markdown]
#     1 sacc get more firing rate as compaire to dots
#     2 But dots having less variace in result

# %%
sns.relplot(data=df, x="time", y="firing_rate", hue="coherence")           #to establish relation betn two variables--relplot

# %% [markdown]
#     Time is near to zero then coherence is high
#     Time is fare away from zero then coherence is less

# %%
sns.relplot(data=dots, x="time", y="firing_rate", hue="align", col="choice", col_wrap=2)

# %% [markdown]
# when we choose tool T1 for firing
#
#     1 for align sacc getting higher firing rate for time is near zero and less than zero
#     2 for align dots getting average firing rate for time is near zero and greater than zero
#
# when we choose tool T2 for firing
#
#     1 for align sacc getting average firing rate for time is near zero and greater than zero
#     2 for align dots getting average firing rate for time is near zero and greater than zero
#
#  conclusion :-
#
#     1 Tool T1 is more preferable than Tool T2
#     2 But Tool T2 has less variance in result of firing rate so when we used T2 then get stable result

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %% [markdown]
#     1 This graph is represent T1 get best result for dots
#     2 But in sacc type T1 result is having more variance so it is uncertain

# %% [markdown]
# ### Vertical barplot

# %%
print(dots.columns)
# Out:
# Index(['align', 'choice', 'time', 'coherence', 'firing_rate'], dtype='object')

# %%
sns.set_context('paper')
 
# create plot
sns.barplot(x = 'align', y = 'firing_rate', data = dots,
            palette = 'PuRd'
            )
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.set_context('paper')
 
# create plot
sns.boxplot(x = 'align', y = 'firing_rate', data = dots,
            palette = 'PuRd'
            )
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
#      1 Dots and sacc are having same mean but its variance is different
#      2 dots are more certain than sacc

# %%
sns.barplot(x = 'align', y = 'firing_rate', hue = 'choice', data = df,
            palette = 'PuRd',
            order = ['dots', 'sacc'],  
            capsize = 0.05,             
            saturation = 8,             
            errcolor = 'gray', errwidth = 2,  
            ci = 'sd'  
            )
plt.legend()
plt.show()

# %% [markdown]
#  In both dots and sacc T1 get more firing rate

# %% [markdown]
# ### Count plot

# %% [markdown]
# The count plot can be thought of as a histogram across a categorical variable.

# %%
sns.set_context('paper')
 
# load dataset
#dots = sns.load_dataset('dots')
# create plot
sns.countplot(x = 'align', hue = 'coherence', data = df, palette = 'magma')
plt.title('dots')
plt.show()

# %% [markdown]
# For both dots and sacc if cohrence is incresses then firing rate is also incresses

# %% [markdown]
# ### Point Plot

# %% [markdown]
# Point plot is used to show point estimates and confidence intervals using scatter plot.
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
#
#
# Point plots can be more useful than bar plots for focusing comparisons between different levels of one or more categorical variables.

# %%
#data = sns.load_dataset("tips") 
sns.pointplot(x="align", y="firing_rate", data=df)
plt.show()

# %%
sns.pointplot(x="align", y="firing_rate", hue="choice",
                   data=df, palette="Accent")
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %% [markdown]
#     firing rate of T1 is more than T2
#     firing rate of T2 is decreses for sacc

# %% [markdown]
# ### Joint Plot

# %% [markdown]
# Joint Plot draws a plot of two variables with bivariate and univariate graphs. It uses the Scatter Plot and Histogram. Joint Plot can also display data using Kernel Density Estimate (KDE) and Hexagons. We can also draw a Regression Line in Scatter Plot.

# %%
sns.set_style("dark")
#tips=sns.load_dataset('tips')
sns.jointplot(x='time', y='firing_rate',data=df)

# %%
# Add regression line to scatter plot and kernel density estimate to histogram
sns.jointplot(x='time', y='firing_rate', data=df, kind='reg')

# %%
# Display hexagons instead of points in scatter plot
sns.jointplot(x='time', y='firing_rate', data=df, kind='hex')

# %% [markdown]
# ### Regression plot

# %% [markdown]
# Regplot is one of the functions in Seaborn that are used to visualize the linear relationship as determined through regression. Also, you‘ll see a slightly shaded portion around the regression line which indicates how much the pints are scattered around a certain area. Here are few of the examples
#
# Now we will plot a discrete x variable and add some jitter. Here you can see that the areas where points are more densely populated have less shaded portion around the regression line and shaded portion is more spread where the points are more scattered.

# %%
ax = sns.regplot(x="time", y="firing_rate", data=df)

# %% [markdown]
# ### Lm Plot

# %% [markdown]
# The regplot function performs a simple linear regression model fit and plot whereas the lmplot function combines regplot and FacetGrid.
#
# The FacetGrid class helps in visualizing the distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels.
#
# It is further important to note that lmplot() is more computationally intensive and is intended as a convenient interface to fit regression models across conditional subsets of a dataset.

# %%
sns.lmplot(x="time", y="firing_rate", data=df)

# %%
sns.lmplot(x="time", y="firing_rate", col="choice", hue="align",
               data=df, col_wrap=2, height=3)

# %% [markdown]
# ### KDE plot

# %% [markdown]
# KDE plot is a Kernel Density Estimate that is used for visualizing the Probability Density of the continuous or non-parametric data variables i.e. we can plot for the univariate or multiple variables altogether.

# %%
iris = sns.load_dataset("iris")

# %%
sns.set_style("dark")
iris = sns.load_dataset("iris")
# Plotting the KDE Plot 
sns.kdeplot(iris.loc[(iris['species']=='setosa'), 
            'sepal_length'], color='b', shade=True, Label='setosa') 
sns.kdeplot(iris.loc[(iris['species']=='virginica'), 
            'sepal_length'], color='r', shade=True, Label='virginica')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:967: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:1015: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:967: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:1015: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# Violin plots also like boxplots summarize numeric data over a set of categories.
#
# They are essentially a box plot with a kernel density estimate (KDE) overlaid along with the range of the box and reflected to make it look nice.
#
# Unlike a box plot, in which all of the plot components correspond to actual data points, the violin plot features a kernel density estimation of the underlying distribution.

# %%
df = sns.load_dataset("dots") 

ax = sns.violinplot(x=df["firing_rate"])

# %%
sns.violinplot(x="align", y="firing_rate", hue="choice",
                    data=df, palette="muted")
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x="align", y="firing_rate", hue="choice",
                    data=df, palette="muted", split=True)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %% [markdown]
# ### Heatmap

# %% [markdown]
# A heatmap is a two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented as colours.
#
# In Seaborn, we can make annotated heatmaps which can be tweaked using Matplotlib as per requirement.
#
# Now if we get the data of the dataset ‘flights’ and transform it by monthly as shown below, it can give us a lot of information about the data.
#
# But this information is in tabular form and can be better displayed by using heatmap as shown below:

# %%
flights=sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flights.pivot("month", "year", "passengers")
print(flights)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(flights,linewidths=1,cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# Now we can also put the respective values in the boxes using the annot parameter of this function

# %%
car_crashes = sns.load_dataset("car_crashes")
corr=car_crashes.corr()
print(corr)
sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlGnBu")
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000
# <AxesSubplot:>

# %% [markdown]
# ### Cluster map

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
sns.clustermap(flights,linewidths=.5,cmap="coolwarm")

# %% [markdown]
# As you can see in this map all the columns and rows that have similar data together and now neither the years nor the months are in order as we saw in the heatmap. We can modify it a bit and only cluster rows or columns, here is how :
#
# flights=sns.load_dataset("flights")
# flights = flights.pivot("month", "year", "passengers

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
sns.clustermap(flights,linewidths=.5,cmap="coolwarm",col_cluster=False)

# %% [markdown]
# ### Facetgrid

# %% [markdown]
# Facet grid forms a matrix of panels defined by row and column by dividing the variables.
#
# Due to panels, a single plot looks like multiple plots. It is very helpful to analyze all combinations in two discrete variables.
#
# The advantage of using Facet is, we can input another variable into the plot.
#
# Now the plot below shows that relation between tips and total bill and also show their relation with variable,i.e gender

# %%
tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(tips, col="time", row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %% [markdown]
# ### Pair Plot

# %% [markdown]
# Pair plot creates a grid of Axes such that each numeric variable in data will be shared across the y-axes across a single row and the x-axes across a single column.
#
# The diagonal plots are treated differently: a univariate distribution plot is drawn to show the marginal distribution of the data in each column.
#
# Pair Plots are a really simple way to visualize relationships between each variable.
#
# It produces a matrix of relationships between each variable in your data for an instant examination of our data as you’ll see in the example below.

# %%
df = sns.load_dataset('iris')
sns.set_style("ticks")
sns.pairplot(df,hue = 'species',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %%
df = sns.load_dataset('dots')
sns.set_style("ticks")
sns.pairplot(df,hue = 'firing_rate',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()
