# %% [markdown]
# #### Q1. Create charts/plots with retail sales dataset and check which chart/graph is best suited for this dataset. Change the plot title , X label, Y label, font size, font color, marker, marker size, line size, marker colors accordingly to make customized plots

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
#sns.set(colour_codes=True)
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('retail_sales.csv.xlsx')
df
# Out:
#          date     sales
# 0  2009-10-01  338630.0
# 1  2009-11-01  339386.0
# 2  2009-12-01  400264.0
# 3  2010-01-01  314640.0
# 4  2010-02-01  311022.0
# ..        ...       ...
# 67 2015-05-01  462615.0
# 68 2015-06-01  448229.0
# 69 2015-07-01  457710.0
# 70 2015-08-01  456340.0
# 71 2015-09-01  430917.0
#
# [72 rows x 2 columns]

# %%
df.describe()
# Out:
#                sales
# count      72.000000
# mean   401710.138889
# std     39999.439045
# min    311022.000000
# 25%    374655.750000
# 50%    398296.500000
# 75%    432892.500000
# max    501232.000000

# %%
plt.plot(df.sales)

# %%
plt.plot(df.sales, marker= 'o')

# %%
plt.plot(df.sales, marker= '*')

# %%
plt.plot(df.sales, marker = '*', ms = 20)

# %%
plt.plot(df.sales, marker='D',ms=5, mec='r',mfc='hotpink')

# %%
plt.plot(df.sales, marker='h',ms=10, mec='r',mfc='c')

# %%
plt.plot(df.sales,linestyle='dotted')

# %%
plt.plot(df.sales,linestyle='dashed')

# %%
plt.plot(df.sales,color='b')

# %%
plt.plot(df.sales, linewidth='10', color='g')

# %%
#y1 = np.array([df.sales])
#y2 = np.array([df.date])

#plt.plot(y1)
#plt.plot(y2)

#plt.show()

# %%
plt.plot( df.date ,df.sales)

# %%
plt.plot(df.sales)
plt.xlabel('dates')
plt.ylabel('sales')
plt.title('retail sales')
# Out:
# Text(0.5, 1.0, 'retail sales')

# %%
plt.plot(df.sales)


font1 = {'family':'serif','color':'red','size':20}
font2 = {'family':'serif','color':'blue','size':15}

plt.xlabel('Dates', fontdict = font2)
plt.ylabel('Sales', fontdict = font2)
plt.title('Retail Sales', fontdict = font1)
# Out:
# Text(0.5, 1.0, 'Retail Sales')

# %%
plt.plot(df.date ,df.sales)


font1 = {'family':'serif','color':'red','size':20}
font2 = {'family':'serif','color':'blue','size':15}

plt.xlabel('Dates', fontdict = font2)
plt.ylabel('Sales', fontdict = font2)
plt.title('Retail Sales', fontdict = font1)

plt.grid()

# %%
plt.plot( df.date , df.sales)


font1 = {'family':'serif','color':'darkred','size':20}
font2 = {'family':'serif','color':'blue','size':15}

plt.xlabel('Dates', fontdict = font2)
plt.ylabel('Sales', fontdict = font2)
plt.title('Retail Sales', fontdict = font1)

plt.grid(color='m',linestyle='--', linewidth='0.75')

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 6)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.grid()

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 1)
plt.plot(x,y)

plt.show()
