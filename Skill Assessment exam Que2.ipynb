# %% [markdown]
# ## Name :- Shraddha Pandit Pawar
# ## Batch no :- ML-18
# ### Que 2
# ### Dataset :- MT Cars Datasets

# %% [markdown]
# #### Importing libraries and data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pip install statsmodels
# Out:
# ...
#
# ...

# %%
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import KNeighborsRegressor

# %%
data = pd.read_csv('mtcars (1).csv.csv')

# %% [markdown]
# ### a)

# %%
x=data[['cyl']]
y=data['hp'].values
model1 = sm.OLS(x,y)
results = model1.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    cyl   R-squared (uncentered):                   0.939
# Model:                            OLS   Adj. R-squared (uncentered):              0.937
# Method:                 Least Squares   F-statistic:                              476.4
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):                    2.23e-20
# Time:                        14:22:10   Log-Likelihood:                         -60.244
# No. Observations:                  32   AIC:                                      122.5
# Df Residuals:                      31   BIC:                                      124.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x=data[['cyl','disp','wt','carb']].values
lr=LinearRegression()
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.2)
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('The mean absolute score is :',mean_absolute_error(lr.predict(X_test),y_test))
# Out:
# The mean absolute score is : 18.016382474468703

# %%
ad=KNeighborsRegressor(metric='euclidean', n_jobs=1, n_neighbors=1,
                    weights='distance')
ad.fit(X_train,y_train)

print('The mean absolute score is :',mean_absolute_error(ad.predict(X_test),y_test))
# Out:
# The mean absolute score is : 45.285714285714285

# %%
 ad=KNeighborsRegressor(metric='euclidean', n_jobs=1, n_neighbors=1,
                    weights='distance')
ad.fit(X_train,y_train)

print('The mean absolute score is :',mean_absolute_error(ad.predict(X_test),y_test))
# Out:
# The mean absolute score is : 45.285714285714285

# %% [markdown]
# ### b)

# %%
df = pd.read_csv('mtcars (1).csv.csv')

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.shape
# Out:
# (32, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
print(df.columns)
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# ### Data cleaning- Checking for null values

# %%
df.isna().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %% [markdown]
# ### There is not any null value in given dataset

# %% [markdown]
# #### Handling Outliers

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='mpg', data=df)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %% [markdown]
# ### Removing Outliers

# %%
df.drop(columns=['carb'])
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.shape
# Out:
# (32, 12)

# %%
duplicate_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-7663385c193f> in <module>
# ----> 1 duplicate_df.shape
#
# NameError: name 'duplicate_df' is not defined

# %%
data=df[df.duplicated()]

# %%
data.shape
# Out:
# (32, 12)

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (32, 12)

# %%
data.isna().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
data.boxplot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# mpg       7.37500
# cyl       4.00000
# disp    205.17500
# hp       83.50000
# drat      0.84000
# wt        1.02875
# qsec      2.00750
# vs        1.00000
# am        1.00000
# gear      1.00000
# carb      2.00000
# dtype: float64

# %%
data1=data[-((data<(Q1-1.5*IQR)) | (data>(Q3+1.5*IQR))).any(axis=1)]
data1.shape
# Out:
# <ipython-input-80-b31e7b0b4176>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data1=data[-((data<(Q1-1.5*IQR)) | (data>(Q3+1.5*IQR))).any(axis=1)]
# (26, 12)

# %%
data1.boxplot
# Out:
# <bound method boxplot_frame of                 model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0           Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1       Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2          Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3      Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4   Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5             Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6          Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7           Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9            Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10          Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11         Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %% [markdown]
# #### c)

# %%
plt.figure(figsize=(16,9)) # Figure size
sns.lineplot(x='model', y='hp', data=data, marker='o', color='indigo') 
plt.title('Horse Power') # Title
plt.xticks(data.model.unique(), rotation=45) 
plt.show()

# %%
x=data['model'].values
y=data['hp'].values
fig, ax = plt.subplots(figsize =(12, 9))   
ax.barh(x, y, color='dodgerblue', edgecolor=(0,0,0)) 
ax.set_title('Horse Power') 
plt.show()

# %%
corr1=data.corr()
corr1
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
my_labels=data['model']
my_colors=['mediumseagreen','mistyrose','teal','navajowhite','purple','gold','thistle','yellowgreen','orange','dimgray','sandybrown','red','cadetblue','pink','navy','mediumorchid','tan','blue','peru','darkgreen','darkorange','indianred' ,"darkseagreen",'saddlebrown','lightcoral','gray', 'slateblue','salmon']
plot = data.plot.pie(y='hp', figsize=(15, 15),
                    colors=my_colors, labels=my_labels, autopct='%1.1f%%', subplots=True)

# %%
ordered=data.sort_values(by=['hp'], ascending=False)
ordered=ordered.reset_index(drop=True)
ordered
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0         Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 1        Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 2            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 3            Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 4     Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 5   Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 6    Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 7           Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 8            Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 9            Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 10         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# ...

# %%
AvgHP=ordered.loc[(ordered['hp'] >= 109) & (ordered['hp'] <= 180)]
AvgHP=AvgHP.reset_index(drop=True)
AvgHP
# Out:
#                 model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0         Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 1          Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 2          Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 3        Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 4   Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5    Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 6         AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 7    Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 8           Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 9            Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10       Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 11          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# ...

# %%
corr2=AvgHP.corr()
sns.heatmap(corr2, cmap="Greens")
# Out:
# <AxesSubplot:>
