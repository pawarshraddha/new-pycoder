# %% [markdown]
# ## Presentation on Support Vector Machine and Decision Tree

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# file:///C:/Users/Admin/RBF3.ppm![image.png](attachment:image.png)

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# lets look at the example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# some definations

# %% [markdown]
# ![all%20def.jpg](attachment:all%20def.jpg)

# %% [markdown]
# ### Entropy : - Amount of impurity is present in that perticular node

# %% [markdown]
# ![Entropy.jpg](attachment:Entropy.jpg)

# %% [markdown]
# ### Gain :- Amount of imformation gain from that perticular node

# %% [markdown]
# ### Gini impurity :- Is a simplified formula of Entropy by using this we calculate impurity

# %% [markdown]
# ![gini.png](attachment:gini.png)
